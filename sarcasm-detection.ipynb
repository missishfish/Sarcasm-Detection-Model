# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/news-headlines-dataset-for-sarcasm-detection/Sarcasm_Headlines_Dataset_v2.json
# /kaggle/input/news-headlines-dataset-for-sarcasm-detection/Sarcasm_Headlines_Dataset.json

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from urllib.parse import urlparse
from nltk.corpus import stopwords 
import re
import nltk
from wordcloud import WordCloud
nltk.download("stopwords")
from sklearn.model_selection import train_test_split, RandomizedSearchCV, RepeatedStratifiedKFold
from sklearn.ensemble import RandomForestClassifier
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve, roc_auc_score, recall_score, f1_score
from lightgbm import LGBMClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Embedding
from tensorflow.keras.optimizers import Adam,SGD,RMSprop
import optuna
import time

import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# .datatable .frame thead tr.colnames {  background-image: url('data:image/png;base64,...');  background-repeat: repeat-x;  background-size: 14px;  height: 28px;}
# </style>

# %% [markdown]
# # Gather Data
# News Headlines dataset for Sarcasm Detection is collected from two news website. TheOnion aims at producing sarcastic versions of current events and we collected all the headlines from News in Brief and News in Photos categories (which are sarcastic). They collect real (and non-sarcastic) news headlines from HuffPost.
#
# Each record consists of three attributes:
# * is_sarcastic: 1 if the record is sarcastic otherwise 0
# * headline: the headline of the news article
# * article_link: link to the original news article. Useful in collecting supplementary data

# %%
data = pd.read_json("../input/news-headlines-dataset-for-sarcasm-detection/Sarcasm_Headlines_Dataset_v2.json", lines=True)
data.head()
# Out:
#    is_sarcastic                                           headline  \
# 0             1  thirtysomething scientists unveil doomsday clo...
# 1             0  dem rep. totally nails why congress is falling...
# 2             0  eat your veggies: 9 deliciously different recipes
# 3             1  inclement weather prevents liar from getting t...
# 4             1  mother comes pretty close to using word 'strea...
#
#                                         article_link
# 0  https://www.theonion.com/thirtysomething-scien...
# 1  https://www.huffingtonpost.com/entry/donna-edw...
# 2  https://www.huffingtonpost.com/entry/eat-your-...
# 3  https://local.theonion.com/inclement-weather-p...
# 4  https://www.theonion.com/mother-comes-pretty-c...

# %% [markdown]
# In this dataset there is not any null value and there is 28619 sentence.

# %%
print("Null Values\n",data.isnull().sum())
print("\nData Shape: " , data.shape)
# Out:
# Null Values
#  is_sarcastic    0
# headline        0
# article_link    0
# dtype: int64
#
# Data Shape:  (28619, 3)

# %%
def find_num_words(data):
    wordlist = []
    splitting_list = data.str.split()
    for i in range(len(splitting_list)):
        for j in range(len(splitting_list[i])):
            wordlist.append(splitting_list[i][j])
            
    wordset = set(wordlist)
    
    print(len(wordset),len(wordlist))

find_num_words(data.headline)
# Out:
# 38234 287620

# %% [markdown]
# # Visualization
# In the first two visualization, we examine the distribution of real and fake data. First graph is a countplot from seaborn. It shows both real and fake news numbers with columnns. Second graph is a pie graph. If we use pie graph, we can examine percentages of distributions.

# %%
print(data.is_sarcastic.value_counts() ,"\n")

fig, ax = plt.subplots(1,2, figsize=(19, 5))
f1 = sns.countplot(data.is_sarcastic, ax = ax[0]);
f1.set_title("Count of real and fake data")
f1.set_ylabel("Count")
f1.set_xlabel("Target")

f2 = plt.pie(data["is_sarcastic"].value_counts().values,explode=[0,0],labels=data.is_sarcastic.value_counts().index, autopct='%1.1f%%')
fig.show()
# Out:
# 0    14985
# 1    13634
# Name: is_sarcastic, dtype: int64

# %% [markdown]
# In the graph below, we examined which sites the real and fake news were obtained from. We used urlparse to get the site name from url.

# %%
def get_netloc(url):
    scheme, netloc, path, params, query, fragment = urlparse(url)
    return netloc

link = []
for i in range(len(data.article_link)):
    link.append(get_netloc(data.article_link[i]))
    
data["link"] = link

# %%
data.link = data["link"].str.replace("local.theonion.com","www.theonion.com").replace("politics.theonion.com","www.theonion.com").replace("entertainment.theonion.com","www.theonion.com").replace("sports.theonion.com","www.theonion.com").replace("ogn.theonion.com","www.theonion.com")
data.link = data.link.str.replace('www.huffingtonpost.comhttp:','www.huffingtonpost.com').replace('www.huffingtonpost.comhttps:','www.huffingtonpost.com')
data.link.value_counts()
# Out:
# www.huffingtonpost.com    14985
# www.theonion.com          13634
# Name: link, dtype: int64

# %%
ax = sns.countplot(x="link",  hue='is_sarcastic', data=data, palette="pastel")
plt.title("Distribution of The Sarcasm According to Site");

# %% [markdown]
# # Preparing Data

# %%
#Removing punctiation marks
def remove_punctuations(text):
    return re.sub('\[[^]]*\]', '', text)

#Removing special characters
def remove_specialchars(text):
    return re.sub("[^a-zA-Z]"," ",text)

#Removal of stopwords and lemmatization
def remove_stopwords_and_lemmatization(text):
    final_text = []
    text = text.lower()
    text = nltk.word_tokenize(text)
    
    for word in text:
        if word not in set(stopwords.words('english')):
            lemma = nltk.WordNetLemmatizer()
            word = lemma.lemmatize(word) 
            final_text.append(word)
    return " ".join(final_text)


#Total function
def cleaning(text):
    text = remove_punctuations(text)
    text = remove_specialchars(text)
    text = remove_stopwords_and_lemmatization(text)
    return text

data['headline']=data['headline'].apply(cleaning)

# %%
text = " ".join(review for review in data.headline)
print ("There are {} words in the combination of all review.".format(len(text)))

# Generate a word cloud image
wordcloud = WordCloud(background_color="white").generate(text)

# Display the generated image:
# the matplotlib way:
plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# There are 1417022 words in the combination of all review.

# %%
data.head()
# Out:
#    is_sarcastic                                           headline  \
# 0             1  thirtysomething scientist unveil doomsday cloc...
# 1             0  dem rep totally nail congress falling short ge...
# 2             0            eat veggie deliciously different recipe
# 3             1       inclement weather prevents liar getting work
# 4             1  mother come pretty close using word streaming ...
#
#                                         article_link                    link
# 0  https://www.theonion.com/thirtysomething-scien...        www.theonion.com
# 1  https://www.huffingtonpost.com/entry/donna-edw...  www.huffingtonpost.com
# 2  https://www.huffingtonpost.com/entry/eat-your-...  www.huffingtonpost.com
# 3  https://local.theonion.com/inclement-weather-p...        www.theonion.com
# 4  https://www.theonion.com/mother-comes-pretty-c...        www.theonion.com

# %% [markdown]
# ## Tokenizing

# %%
sentences = data["headline"].values.tolist()
target = data["is_sarcastic"].values.tolist()

# %%
print(sentences[:2])
print(target[:2])
# Out:
# ['thirtysomething scientist unveil doomsday clock hair loss', 'dem rep totally nail congress falling short gender racial equality']
# [1, 0]

# %%
num_words = 1000
tokenizer = Tokenizer(num_words=num_words)

tokenizer.fit_on_texts(sentences)
tokens = tokenizer.texts_to_sequences(sentences)

numTokens = [len(token) for token in tokens]
numTokens = np.array(numTokens)
print("Tokens'mean",np.mean(numTokens))
print("Max", np.max(numTokens))
print("Argmax", np.argmax(numTokens))
# Out:
# Tokens'mean 3.7437017366085468
# Max 31
# Argmax 7302

# %%
#Longest one
sentences[7302]
# Out:
# 'hot wheel ranked number one toy rolling ramp knocking domino send marble funnel dropping onto teeter totter yank string causing pulley system raise wooden block propelling series twine roller unwind spring launching tennis ball across room inching tire slope hit power switch activating table fan blow toy ship nail attached across kiddie pool popping water balloon fill cup weighing lever force basketball track nudging broomstick axis rotate allowing golf ball roll sideways coffee mug tumble row hardcover book handle catch hook attached lever cause wooden mallet slam serving spoon catapulting small ball cup attached ribbon lazy susan spin push battery incline plane tipping salt shaker season omelet'

# %%
max_tokens = int(np.mean(numTokens) + 2*np.std(numTokens))
print("Calculated maximum number of tokens :",max_tokens)
print("What percentage of the data fits this average? :",np.sum(numTokens < max_tokens) / len(numTokens))
# Out:
# Calculated maximum number of tokens : 7
# What percentage of the data fits this average? : 0.9099898668716587

# %%
padding_data = pad_sequences(tokens, maxlen=max_tokens)
print(padding_data.shape)
print(len(target))
# Out:
# (28619, 7)
# 28619

# %% [markdown]
# # Model Building

# %%
X_train, X_test, y_train, y_test = train_test_split(padding_data, data.is_sarcastic, random_state=1, test_size=0.15, stratify=data.is_sarcastic)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, random_state=1, test_size=0.1, stratify=y_train)

# %%
def objective(trial):
    # Parameters
    L2 = trial.suggest_float("l", 1e-5, 1e-2, log=True)
    EMBEDDING_SIZE = trial.suggest_int("embedding_size", 10, 50, step=10)
    BATCH_SIZE = trial.suggest_int("batch_size", 16, 64, step=8)
    EPOCHS = trial.suggest_int("epochs", 10,30, step=10)
    LR = trial.suggest_float("learning_rate", 1e-5, 1e-2, log=True)
    OPT = trial.suggest_categorical("optimizer", [Adam, SGD, RMSprop])
    

    # Model
    """base_model = model(include_top=False, weights="imagenet", pooling="max")
    for layer in base_model.layers:
        layer.trainable = False
    x = base_model.output
    predictions = Dense(train_generator.num_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)"""
    
    model = Sequential()
    model.add(Embedding(input_dim = num_words,
                        output_dim=EMBEDDING_SIZE,
                        input_length=max_tokens,
                        name='embedding_layer'))
    
    model.add(GRU(units=128, return_sequences=True, kernel_regularizer = tf.keras.regularizers.l2(l=L2)))
    model.add(GRU(units=64,return_sequences=True, kernel_regularizer = tf.keras.regularizers.l2(l=L2)))
    model.add(GRU(units=32))
    model.add(Dense(16, activation="relu"))
    model.add(Dense(1, activation='sigmoid'))

 
    model.compile(optimizer=OPT(lr=LR), loss='binary_crossentropy', metrics=['accuracy'])

    H = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=EPOCHS, batch_size=BATCH_SIZE)

    val_loss, val_acc = model.evaluate(X_test,y_test)
    
    return val_loss # optuna değerlendirmesini en küçük değere göre yapıyor o yüzden loss döndürdüm. Accuracy döndürdüğümde acc büyüdükçe bunu kötü bir şeymiş gibi algıladı.


# Default Sampler is Tree-structured Parzen Estimator algorithm

study = optuna.create_study()
start = time.time()
study.optimize(objective, n_trials=5)
end = time.time()
# Out:
# [I 2023-12-12 22:15:57,093] A new study created in memory with name: no-name-6bd9efdd-8f64-4e80-878c-d8d860158309
# Epoch 1/10
# 1369/1369 [==============================] - 20s 7ms/step - loss: 0.6440 - accuracy: 0.6268 - val_loss: 0.5363 - val_accuracy: 0.7296
# Epoch 2/10
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.5162 - accuracy: 0.7437 - val_loss: 0.5294 - val_accuracy: 0.7271
# Epoch 3/10
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.5046 - accuracy: 0.7529 - val_loss: 0.5246 - val_accuracy: 0.7320
# Epoch 4/10
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.4867 - accuracy: 0.7631 - val_loss: 0.5207 - val_accuracy: 0.7415
# Epoch 5/10
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.4709 - accuracy: 0.7710 - val_loss: 0.5323 - val_accuracy: 0.7374
# Epoch 6/10
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.4648 - accuracy: 0.7763 - val_loss: 0.5266 - val_accuracy: 0.7394
# Epoch 7/10
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.4587 - accuracy: 0.7791 - val_loss: 0.5264 - val_accuracy: 0.7382
# Epoch 8/10
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.4466 - accuracy: 0.7877 - val_loss: 0.5352 - val_accuracy: 0.7357
# Epoch 9/10
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.4443 - accuracy: 0.7894 - val_loss: 0.5360 - val_accuracy: 0.7374
# Epoch 10/10
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.4389 - accuracy: 0.7898 - val_loss: 0.5433 - val_accuracy: 0.7316
# 135/135 [==============================] - 0s 3ms/step - loss: 0.5415 - accuracy: 0.7240
# [I 2023-12-12 22:17:33,831] Trial 0 finished with value: 0.5414899587631226 and parameters: {'l': 0.00018078893506628065, 'embedding_size': 50, 'batch_size': 16, 'epochs': 10, 'learning_rate': 0.0003030813360635394, 'optimizer': <class 'tensorflow.python.keras.optimizer_v2.adam.Adam'>}. Best is trial 0 with value: 0.5414899587631226.
# Epoch 1/20
# 391/391 [==============================] - 8s 8ms/step - loss: 1.4249 - accuracy: 0.5178 - val_loss: 1.1132 - val_accuracy: 0.5898
# Epoch 2/20
# 391/391 [==============================] - 2s 6ms/step - loss: 1.0179 - accuracy: 0.6442 - val_loss: 0.7858 - val_accuracy: 0.7152
# Epoch 3/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7378 - accuracy: 0.7230 - val_loss: 0.6649 - val_accuracy: 0.7296
# Epoch 4/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.6214 - accuracy: 0.7464 - val_loss: 0.6072 - val_accuracy: 0.7267
# Epoch 5/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.5743 - accuracy: 0.7471 - val_loss: 0.5818 - val_accuracy: 0.7349
# Epoch 6/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.5445 - accuracy: 0.7560 - val_loss: 0.5695 - val_accuracy: 0.7345
# Epoch 7/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.5347 - accuracy: 0.7562 - val_loss: 0.5628 - val_accuracy: 0.7333
# Epoch 8/20
# 391/391 [==============================] - 3s 7ms/step - loss: 0.5287 - accuracy: 0.7506 - val_loss: 0.5652 - val_accuracy: 0.7271
# Epoch 9/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.5253 - accuracy: 0.7513 - val_loss: 0.5587 - val_accuracy: 0.7304
# Epoch 10/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.5200 - accuracy: 0.7554 - val_loss: 0.5538 - val_accuracy: 0.7345
# Epoch 11/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.5135 - accuracy: 0.7596 - val_loss: 0.5517 - val_accuracy: 0.7345
# Epoch 12/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.5166 - accuracy: 0.7540 - val_loss: 0.5508 - val_accuracy: 0.7324
# Epoch 13/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.5052 - accuracy: 0.7610 - val_loss: 0.5557 - val_accuracy: 0.7263
# Epoch 14/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.5102 - accuracy: 0.7565 - val_loss: 0.5564 - val_accuracy: 0.7271
# Epoch 15/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.5045 - accuracy: 0.7587 - val_loss: 0.5464 - val_accuracy: 0.7349
# Epoch 16/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.5085 - accuracy: 0.7564 - val_loss: 0.5446 - val_accuracy: 0.7320
# Epoch 17/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.4960 - accuracy: 0.7647 - val_loss: 0.5420 - val_accuracy: 0.7378
# Epoch 18/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.4962 - accuracy: 0.7626 - val_loss: 0.5412 - val_accuracy: 0.7337
# Epoch 19/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.4931 - accuracy: 0.7632 - val_loss: 0.5400 - val_accuracy: 0.7349
# Epoch 20/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.4838 - accuracy: 0.7737 - val_loss: 0.5397 - val_accuracy: 0.7349
# 135/135 [==============================] - 0s 3ms/step - loss: 0.5408 - accuracy: 0.7386
# [I 2023-12-12 22:18:29,119] Trial 1 finished with value: 0.5407881736755371 and parameters: {'l': 0.0035574257276487402, 'embedding_size': 50, 'batch_size': 56, 'epochs': 20, 'learning_rate': 7.40219167658729e-05, 'optimizer': <class 'tensorflow.python.keras.optimizer_v2.adam.Adam'>}. Best is trial 1 with value: 0.5407881736755371.
# Epoch 1/30
# 391/391 [==============================] - 7s 8ms/step - loss: 0.7584 - accuracy: 0.5154 - val_loss: 0.7573 - val_accuracy: 0.5236
# Epoch 2/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7577 - accuracy: 0.5192 - val_loss: 0.7571 - val_accuracy: 0.5236
# Epoch 3/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7573 - accuracy: 0.5223 - val_loss: 0.7569 - val_accuracy: 0.5236
# Epoch 4/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7569 - accuracy: 0.5236 - val_loss: 0.7566 - val_accuracy: 0.5236
# Epoch 5/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7561 - accuracy: 0.5302 - val_loss: 0.7564 - val_accuracy: 0.5236
# Epoch 6/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7565 - accuracy: 0.5239 - val_loss: 0.7562 - val_accuracy: 0.5236
# Epoch 7/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7558 - accuracy: 0.5291 - val_loss: 0.7560 - val_accuracy: 0.5236
# Epoch 8/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7559 - accuracy: 0.5249 - val_loss: 0.7557 - val_accuracy: 0.5236
# Epoch 9/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7556 - accuracy: 0.5260 - val_loss: 0.7555 - val_accuracy: 0.5236
# Epoch 10/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7557 - accuracy: 0.5220 - val_loss: 0.7553 - val_accuracy: 0.5236
# Epoch 11/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7553 - accuracy: 0.5242 - val_loss: 0.7551 - val_accuracy: 0.5236
# Epoch 12/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7557 - accuracy: 0.5178 - val_loss: 0.7548 - val_accuracy: 0.5236
# Epoch 13/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7550 - accuracy: 0.5227 - val_loss: 0.7546 - val_accuracy: 0.5236
# Epoch 14/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7550 - accuracy: 0.5211 - val_loss: 0.7544 - val_accuracy: 0.5236
# Epoch 15/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7547 - accuracy: 0.5208 - val_loss: 0.7542 - val_accuracy: 0.5236
# Epoch 16/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7541 - accuracy: 0.5256 - val_loss: 0.7539 - val_accuracy: 0.5236
# Epoch 17/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7539 - accuracy: 0.5247 - val_loss: 0.7537 - val_accuracy: 0.5236
# Epoch 18/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7539 - accuracy: 0.5233 - val_loss: 0.7534 - val_accuracy: 0.5236
# Epoch 19/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7537 - accuracy: 0.5232 - val_loss: 0.7532 - val_accuracy: 0.5236
# Epoch 20/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7538 - accuracy: 0.5182 - val_loss: 0.7529 - val_accuracy: 0.5236
# Epoch 21/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7533 - accuracy: 0.5215 - val_loss: 0.7527 - val_accuracy: 0.5236
# Epoch 22/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7531 - accuracy: 0.5224 - val_loss: 0.7524 - val_accuracy: 0.5236
# Epoch 23/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7529 - accuracy: 0.5201 - val_loss: 0.7521 - val_accuracy: 0.5236
# Epoch 24/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7523 - accuracy: 0.5234 - val_loss: 0.7519 - val_accuracy: 0.5236
# Epoch 25/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7511 - accuracy: 0.5338 - val_loss: 0.7516 - val_accuracy: 0.5236
# Epoch 26/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7521 - accuracy: 0.5211 - val_loss: 0.7512 - val_accuracy: 0.5236
# Epoch 27/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7515 - accuracy: 0.5241 - val_loss: 0.7509 - val_accuracy: 0.5236
# Epoch 28/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7513 - accuracy: 0.5241 - val_loss: 0.7506 - val_accuracy: 0.5236
# Epoch 29/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7506 - accuracy: 0.5275 - val_loss: 0.7503 - val_accuracy: 0.5236
# Epoch 30/30
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7502 - accuracy: 0.5280 - val_loss: 0.7500 - val_accuracy: 0.5245
# 135/135 [==============================] - 0s 3ms/step - loss: 0.7503 - accuracy: 0.5243
# [I 2023-12-12 22:19:43,054] Trial 2 finished with value: 0.7503310441970825 and parameters: {'l': 0.0002892163147388181, 'embedding_size': 40, 'batch_size': 56, 'epochs': 30, 'learning_rate': 0.0064566461775236545, 'optimizer': <class 'tensorflow.python.keras.optimizer_v2.gradient_descent.SGD'>}. Best is trial 1 with value: 0.5407881736755371.
# Epoch 1/20
# 1369/1369 [==============================] - 13s 6ms/step - loss: 0.7072 - accuracy: 0.5395 - val_loss: 0.6592 - val_accuracy: 0.6383
# Epoch 2/20
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.6285 - accuracy: 0.6581 - val_loss: 0.5693 - val_accuracy: 0.7008
# Epoch 3/20
# 1369/1369 [==============================] - 9s 6ms/step - loss: 0.5571 - accuracy: 0.7158 - val_loss: 0.5514 - val_accuracy: 0.7148
# Epoch 4/20
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.5350 - accuracy: 0.7285 - val_loss: 0.5406 - val_accuracy: 0.7296
# Epoch 5/20
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.5183 - accuracy: 0.7381 - val_loss: 0.5348 - val_accuracy: 0.7328
# Epoch 6/20
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.5099 - accuracy: 0.7454 - val_loss: 0.5349 - val_accuracy: 0.7267
# Epoch 7/20
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.4995 - accuracy: 0.7514 - val_loss: 0.5315 - val_accuracy: 0.7341
# Epoch 8/20
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.5006 - accuracy: 0.7502 - val_loss: 0.5306 - val_accuracy: 0.7324
# Epoch 9/20
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.4891 - accuracy: 0.7550 - val_loss: 0.5302 - val_accuracy: 0.7320
# Epoch 10/20
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.4926 - accuracy: 0.7540 - val_loss: 0.5305 - val_accuracy: 0.7300
# Epoch 11/20
# 1369/1369 [==============================] - 9s 7ms/step - loss: 0.4909 - accuracy: 0.7554 - val_loss: 0.5281 - val_accuracy: 0.7333
# Epoch 12/20
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.4865 - accuracy: 0.7602 - val_loss: 0.5285 - val_accuracy: 0.7316
# Epoch 13/20
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.4923 - accuracy: 0.7540 - val_loss: 0.5295 - val_accuracy: 0.7328
# Epoch 14/20
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.4817 - accuracy: 0.7593 - val_loss: 0.5282 - val_accuracy: 0.7296
# Epoch 15/20
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.4877 - accuracy: 0.7577 - val_loss: 0.5295 - val_accuracy: 0.7328
# Epoch 16/20
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.4934 - accuracy: 0.7531 - val_loss: 0.5308 - val_accuracy: 0.7287
# Epoch 17/20
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.4847 - accuracy: 0.7585 - val_loss: 0.5333 - val_accuracy: 0.7259
# Epoch 18/20
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.4831 - accuracy: 0.7594 - val_loss: 0.5257 - val_accuracy: 0.7291
# Epoch 19/20
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.4858 - accuracy: 0.7544 - val_loss: 0.5267 - val_accuracy: 0.7324
# Epoch 20/20
# 1369/1369 [==============================] - 8s 6ms/step - loss: 0.4798 - accuracy: 0.7641 - val_loss: 0.5267 - val_accuracy: 0.7287
# 135/135 [==============================] - 0s 3ms/step - loss: 0.5270 - accuracy: 0.7319
# [I 2023-12-12 22:22:32,141] Trial 3 finished with value: 0.5269841551780701 and parameters: {'l': 0.00012187982255310876, 'embedding_size': 10, 'batch_size': 16, 'epochs': 20, 'learning_rate': 3.839753364454998e-05, 'optimizer': <class 'tensorflow.python.keras.optimizer_v2.adam.Adam'>}. Best is trial 3 with value: 0.5269841551780701.
# Epoch 1/20
# 913/913 [==============================] - 11s 8ms/step - loss: 0.6698 - accuracy: 0.5748 - val_loss: 0.5602 - val_accuracy: 0.7102
# Epoch 2/20
# 913/913 [==============================] - 6s 7ms/step - loss: 0.5262 - accuracy: 0.7326 - val_loss: 0.5332 - val_accuracy: 0.7217
# Epoch 3/20
# 913/913 [==============================] - 6s 7ms/step - loss: 0.5086 - accuracy: 0.7479 - val_loss: 0.5250 - val_accuracy: 0.7316
# Epoch 4/20
# 913/913 [==============================] - 6s 6ms/step - loss: 0.5025 - accuracy: 0.7518 - val_loss: 0.5618 - val_accuracy: 0.7053
# Epoch 5/20
# 913/913 [==============================] - 6s 6ms/step - loss: 0.5025 - accuracy: 0.7477 - val_loss: 0.5252 - val_accuracy: 0.7250
# Epoch 6/20
# 913/913 [==============================] - 6s 7ms/step - loss: 0.4958 - accuracy: 0.7512 - val_loss: 0.5285 - val_accuracy: 0.7349
# Epoch 7/20
# 913/913 [==============================] - 6s 7ms/step - loss: 0.4947 - accuracy: 0.7539 - val_loss: 0.5277 - val_accuracy: 0.7345
# Epoch 8/20
# 913/913 [==============================] - 6s 7ms/step - loss: 0.4924 - accuracy: 0.7578 - val_loss: 0.5212 - val_accuracy: 0.7328
# Epoch 9/20
# 913/913 [==============================] - 6s 7ms/step - loss: 0.4906 - accuracy: 0.7518 - val_loss: 0.5205 - val_accuracy: 0.7365
# Epoch 10/20
# 913/913 [==============================] - 6s 7ms/step - loss: 0.5007 - accuracy: 0.7493 - val_loss: 0.5193 - val_accuracy: 0.7341
# Epoch 11/20
# 913/913 [==============================] - 6s 7ms/step - loss: 0.4976 - accuracy: 0.7522 - val_loss: 0.5178 - val_accuracy: 0.7357
# Epoch 12/20
# 913/913 [==============================] - 6s 7ms/step - loss: 0.4952 - accuracy: 0.7548 - val_loss: 0.5445 - val_accuracy: 0.7094
# Epoch 13/20
# 913/913 [==============================] - 6s 7ms/step - loss: 0.4971 - accuracy: 0.7540 - val_loss: 0.5160 - val_accuracy: 0.7287
# Epoch 14/20
# 913/913 [==============================] - 6s 7ms/step - loss: 0.4875 - accuracy: 0.7602 - val_loss: 0.5192 - val_accuracy: 0.7374
# Epoch 15/20
# 913/913 [==============================] - 6s 7ms/step - loss: 0.4903 - accuracy: 0.7565 - val_loss: 0.5300 - val_accuracy: 0.7316
# Epoch 16/20
# 913/913 [==============================] - 6s 7ms/step - loss: 0.4911 - accuracy: 0.7594 - val_loss: 0.5154 - val_accuracy: 0.7333
# Epoch 17/20
# 913/913 [==============================] - 6s 7ms/step - loss: 0.4896 - accuracy: 0.7600 - val_loss: 0.5265 - val_accuracy: 0.7361
# Epoch 18/20
# 913/913 [==============================] - 6s 7ms/step - loss: 0.4905 - accuracy: 0.7562 - val_loss: 0.5239 - val_accuracy: 0.7390
# Epoch 19/20
# 913/913 [==============================] - 6s 7ms/step - loss: 0.4899 - accuracy: 0.7594 - val_loss: 0.5552 - val_accuracy: 0.7390
# Epoch 20/20
# 913/913 [==============================] - 6s 7ms/step - loss: 0.4855 - accuracy: 0.7642 - val_loss: 0.5213 - val_accuracy: 0.7324
# 135/135 [==============================] - 0s 3ms/step - loss: 0.5275 - accuracy: 0.7303
# [I 2023-12-12 22:24:39,633] Trial 4 finished with value: 0.527522623538971 and parameters: {'l': 0.0006429705815337694, 'embedding_size': 10, 'batch_size': 24, 'epochs': 20, 'learning_rate': 0.0010458459439847481, 'optimizer': <class 'tensorflow.python.keras.optimizer_v2.rmsprop.RMSprop'>}. Best is trial 3 with value: 0.5269841551780701.

# %%
best_params = study.best_params
print(best_params)
print("model took %0.2f seconds to train" % (end - start))
# Out:
# {'l': 0.00012187982255310876, 'embedding_size': 10, 'batch_size': 16, 'epochs': 20, 'learning_rate': 3.839753364454998e-05, 'optimizer': <class 'tensorflow.python.keras.optimizer_v2.adam.Adam'>}
# model took 522.54 seconds to train

# %%
EMBEDDING_SIZE = 40

model = Sequential()
model.add(Embedding(input_dim = num_words,
                    output_dim=EMBEDDING_SIZE,
                    input_length=max_tokens,
                    name='embedding_layer'))
model.add(GRU(units=128, return_sequences=True, kernel_regularizer = tf.keras.regularizers.l2(l=1.367675698620851e-05)))
model.add(GRU(units=64,return_sequences=True, kernel_regularizer = tf.keras.regularizers.l2(l=1.367675698620851e-05)))
model.add(GRU(units=32))
#model.add(Dense(16, activation="relu"))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_layer (Embedding)  (None, 7, 40)             40000
# _________________________________________________________________
# gru_15 (GRU)                 (None, 7, 128)            65280
# _________________________________________________________________
# gru_16 (GRU)                 (None, 7, 64)             37248
# _________________________________________________________________
# gru_17 (GRU)                 (None, 32)                9408
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 151,969
# Trainable params: 151,969
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="binary_crossentropy", optimizer = RMSprop(lr=8.74355057651944e-05), metrics=["accuracy"])
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=30, batch_size=40)
# Out:
# Epoch 1/30
# 548/548 [==============================] - 8s 8ms/step - loss: 0.6890 - accuracy: 0.5382 - val_loss: 0.6196 - val_accuracy: 0.6589
# Epoch 2/30
# 548/548 [==============================] - 3s 6ms/step - loss: 0.5889 - accuracy: 0.6815 - val_loss: 0.5594 - val_accuracy: 0.7102
# Epoch 3/30
# 548/548 [==============================] - 3s 6ms/step - loss: 0.5382 - accuracy: 0.7156 - val_loss: 0.5472 - val_accuracy: 0.7139
# Epoch 4/30
# 548/548 [==============================] - 4s 6ms/step - loss: 0.5221 - accuracy: 0.7321 - val_loss: 0.5318 - val_accuracy: 0.7296
# Epoch 5/30
# 548/548 [==============================] - 3s 6ms/step - loss: 0.5049 - accuracy: 0.7446 - val_loss: 0.5267 - val_accuracy: 0.7337
# Epoch 6/30
# 548/548 [==============================] - 3s 6ms/step - loss: 0.5019 - accuracy: 0.7494 - val_loss: 0.5411 - val_accuracy: 0.7164
# Epoch 7/30
# 548/548 [==============================] - 4s 7ms/step - loss: 0.4927 - accuracy: 0.7539 - val_loss: 0.5335 - val_accuracy: 0.7230
# Epoch 8/30
# 548/548 [==============================] - 4s 7ms/step - loss: 0.4950 - accuracy: 0.7511 - val_loss: 0.5232 - val_accuracy: 0.7316
# Epoch 9/30
# 548/548 [==============================] - 4s 7ms/step - loss: 0.4948 - accuracy: 0.7527 - val_loss: 0.5226 - val_accuracy: 0.7337
# Epoch 10/30
# 548/548 [==============================] - 4s 6ms/step - loss: 0.4954 - accuracy: 0.7533 - val_loss: 0.5262 - val_accuracy: 0.7279
# Epoch 11/30
# 548/548 [==============================] - 3s 6ms/step - loss: 0.4844 - accuracy: 0.7550 - val_loss: 0.5186 - val_accuracy: 0.7406
# Epoch 12/30
# 548/548 [==============================] - 3s 6ms/step - loss: 0.4830 - accuracy: 0.7576 - val_loss: 0.5182 - val_accuracy: 0.7365
# Epoch 13/30
# 548/548 [==============================] - 3s 6ms/step - loss: 0.4876 - accuracy: 0.7600 - val_loss: 0.5167 - val_accuracy: 0.7353
# Epoch 14/30
# 548/548 [==============================] - 3s 6ms/step - loss: 0.4816 - accuracy: 0.7624 - val_loss: 0.5178 - val_accuracy: 0.7365
# Epoch 15/30
# 548/548 [==============================] - 4s 6ms/step - loss: 0.4722 - accuracy: 0.7667 - val_loss: 0.5154 - val_accuracy: 0.7382
# Epoch 16/30
# 548/548 [==============================] - 4s 7ms/step - loss: 0.4796 - accuracy: 0.7615 - val_loss: 0.5151 - val_accuracy: 0.7419
# Epoch 17/30
# 548/548 [==============================] - 4s 6ms/step - loss: 0.4793 - accuracy: 0.7599 - val_loss: 0.5185 - val_accuracy: 0.7333
# Epoch 18/30
# 548/548 [==============================] - 4s 7ms/step - loss: 0.4797 - accuracy: 0.7643 - val_loss: 0.5140 - val_accuracy: 0.7382
# Epoch 19/30
# 548/548 [==============================] - 3s 6ms/step - loss: 0.4762 - accuracy: 0.7624 - val_loss: 0.5121 - val_accuracy: 0.7406
# Epoch 20/30
# 548/548 [==============================] - 3s 6ms/step - loss: 0.4683 - accuracy: 0.7701 - val_loss: 0.5117 - val_accuracy: 0.7427
# Epoch 21/30
# 548/548 [==============================] - 4s 7ms/step - loss: 0.4721 - accuracy: 0.7678 - val_loss: 0.5177 - val_accuracy: 0.7390
# Epoch 22/30
# 548/548 [==============================] - 4s 6ms/step - loss: 0.4707 - accuracy: 0.7672 - val_loss: 0.5134 - val_accuracy: 0.7443
# Epoch 23/30
# 548/548 [==============================] - 4s 6ms/step - loss: 0.4668 - accuracy: 0.7689 - val_loss: 0.5188 - val_accuracy: 0.7398
# Epoch 24/30
# 548/548 [==============================] - 4s 7ms/step - loss: 0.4598 - accuracy: 0.7765 - val_loss: 0.5161 - val_accuracy: 0.7427
# Epoch 25/30
# 548/548 [==============================] - 4s 7ms/step - loss: 0.4699 - accuracy: 0.7679 - val_loss: 0.5158 - val_accuracy: 0.7415
# Epoch 26/30
# 548/548 [==============================] - 4s 6ms/step - loss: 0.4597 - accuracy: 0.7767 - val_loss: 0.5152 - val_accuracy: 0.7435
# Epoch 27/30
# 548/548 [==============================] - 4s 7ms/step - loss: 0.4618 - accuracy: 0.7750 - val_loss: 0.5157 - val_accuracy: 0.7402
# Epoch 28/30
# 548/548 [==============================] - 4s 7ms/step - loss: 0.4603 - accuracy: 0.7746 - val_loss: 0.5151 - val_accuracy: 0.7427
# Epoch 29/30
# 548/548 [==============================] - 4s 6ms/step - loss: 0.4638 - accuracy: 0.7710 - val_loss: 0.5178 - val_accuracy: 0.7431
# Epoch 30/30
# 548/548 [==============================] - 4s 6ms/step - loss: 0.4529 - accuracy: 0.7816 - val_loss: 0.5195 - val_accuracy: 0.7431

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')
